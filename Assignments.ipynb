# %% [markdown]
# # *QUESTION 1.1*

# %% [markdown]
# # 1. What is the difference between static and dynamic variables in Python?
# Static variables are class-level variables shared among all instances of a class, declared within the class but outside any method. Dynamic variables are instance-level variables unique to each instance of a class, usually declared within methods.

# %%
class MyClass:
    static_var = 10 

    def __init__(self, value):
        self.dynamic_var = value 


print(MyClass.static_var)


obj1 = MyClass(20)
obj2 = MyClass(30)


print(obj1.dynamic_var)
print(obj2.dynamic_var)

# %% [markdown]
# # 2. Explain the purpose of "pop()", "popitem()", and "clear()" in a dictionary with suitable examples.
# The "pop()" method removes the specified key and returns the corresponding value. If the key does not exist, it throws a KeyError unless a default value is provided. "popitem()" removes and returns the last inserted key-value pair as a tuple. "clear()" removes all items from the dictionary.

# %%
my_dict = {'a': 1, 'b': 2, 'c': 3}
print(my_dict.pop('b'))  
print(my_dict) 
print(my_dict.popitem()) 
print(my_dict)  
my_dict.clear()
print(my_dict)

# %% [markdown]
# # 3. What do you mean by FrozenSet? Explain it with suitable examples.
# A frozenset is an immutable version of a Python set. It cannot be changed after creation, making it hashable and usable as a key in a dictionary or an element of another set.

# %%
fs = frozenset([1, 2, 3, 4])
print(fs)

# %% [markdown]
# # 4. Differentiate between mutable and immutable data types in Python and give examples of mutable and immutable data types.
# Mutable data types can be changed after creation, while immutable data types cannot be altered once created. Examples of mutable data types include lists, dictionaries, and sets. Examples of immutable data types include strings, tuples, and frozensets.

# %%
my_list = [1, 2, 3]
my_list.append(4)
print(my_list)

# %% [markdown]
# # 5. What is __init__? Explain with an example.
# __init__ is a special method in Python classes, known as a constructor. It is automatically invoked when a new object of the class is instantiated, initializing the object's attributes.

# %%
class MyClass:
    def __init__(self, name):
        self.name = name

obj = MyClass("John")
print(obj.name)

# %% [markdown]
# # 6. What is a docstring in Python? Explain with an example.
# A docstring is a special string literal used to document a module, class, function, or method in Python. It is placed as the first statement in the definition and is accessible via the __doc__ attribute.

# %%
def my_function():
    """This is a docstring."""
    return "Hello, World!"

print(my_function.__doc__)

# %% [markdown]
# # 7. What are unit tests in Python?
# Unit tests are tests that validate the functionality of individual units of code, such as functions or methods, in isolation. They help ensure that each unit performs as expected.

# %% [markdown]
# # 8. What is break, continue, and pass in Python?
# break terminates the loop, continue skips the current iteration and proceeds to the next one, and pass is a null statement used as a placeholder.

# %%
for i in range(5):
    if i == 2:
        continue
    elif i == 3:
        break
    else:
        pass
    print(i)

# %% [markdown]
# # 9. What is the use of self in Python?
# self represents the instance of the class in methods, allowing access to the attributes and methods of the class. It is the first parameter in instance methods.

# %%
class MyClass:
    def __init__(self, value):
        self.value = value

    def display(self):
        print(self.value)

obj = MyClass(10)
obj.display()

# %% [markdown]
# # 10. What are global, protected, and private attributes in Python?
# Global attributes are accessible anywhere in the code. Protected attributes are indicated by a single underscore and are intended for use within the class and its subclasses. Private attributes are indicated by a double underscore and are intended for use only within the class.

# %%
class MyClass:
    global_var = "I am global"
    _protected_var = "I am protected"
    __private_var = "I am private"

# %% [markdown]
# # 11. What are modules and packages in Python?
# Modules are files containing Python code, such as functions and classes. Packages are collections of modules organized in directories with an __init__.py file, allowing hierarchical structuring.

# %%
# Module example (module.py)
def hello():
    print("Hello, World!")

# Package example (mypackage/__init__.py, mypackage/module.py)
# mypackage/__init__.py
# (Empty file to mark directory as a package)

# mypackage/module.py
def hello():
    print("Hello from the package!")

# %% [markdown]
# # 12. What are lists and tuples? What is the key difference between the two?
# Lists and tuples are both sequence data types in Python. Lists are mutable, meaning their elements can be changed, while tuples are immutable and cannot be modified after creation.

# %%
# List example
my_list = [1, 2, 3]
my_list.append(4)
print(my_list)  
# Tuple example
my_tuple = (1, 2, 3)
# my_tuple[0] = 4

# %% [markdown]
# # 13. What is an Interpreted language & dynamically typed language? Write 5 differences between them.
# An interpreted language executes code line by line at runtime, while a dynamically typed language determines data types at runtime rather than compile-time.
#
#
# Differences:
# 1. Compilation: Interpreted languages are executed line-by-line, while compiled languages are converted into machine code before execution.
# 2. Performance: Interpreted languages are generally slower than compiled languages due to real-time interpretation.
# 3. Flexibility: Dynamically typed languages allow variables to change types, while statically typed languages require explicit type declarations.
# 4. Error Checking: Dynamically typed languages catch type errors at runtime, while statically typed languages catch them at compile-time.
# 5. Type Declaration: Interpreted languages often do not require explicit type declarations, unlike statically typed languages.

# %%
# Dynamically typed example
x = 10
x = "Hello"  # No error

# Statically typed example (Python doesn't support static typing directly)
# int x = 10
# x = "Hello"  # This would raise a type error in statically typed languages

# %% [markdown]
# # 14. What are Dict and List comprehensions?
# Dict and List comprehensions provide a concise way to create dictionaries and lists using a single line of code, often with a for loop and optional conditions.

# %%
# List comprehension
squares = [x**2 for x in range(5)]
print(squares)  # Output: [0, 1, 4, 9, 16]

# Dict comprehension
square_dict = {x: x**2 for x in range(5)}
print(square_dict)

# %% [markdown]
# # 15. What are decorators in Python? Explain it with an example. Write down its use cases.
# Decorators are functions that modify the behavior of other functions or methods. They are used to add functionality to existing code in a reusable way.

# %%
def decorator_function(original_function):
    def wrapper_function():
        print("Wrapper executed before {}".format(original_function.__name__))
        return original_function()
    return wrapper_function

@decorator_function
def display():
    print("Display function ran")

display()

# %% [markdown]
# # 16. How is memory managed in Python?
# Memory in Python is managed by the Python Memory Manager, which handles allocation and deallocation of memory. It uses reference counting and garbage collection to manage memory efficiently.

# %%
# Reference counting example
a = [1, 2, 3]
b = a
# Garbage collection example
import gc
gc.collect()

# %% [markdown]
# # 17. What is lambda in Python? Why is it used?
# Lambda functions are anonymous functions defined with the lambda keyword. They are used for creating small, one-time use functions without the need to formally define them.

# %%
add = lambda x, y: x + y
print(add(2, 3))

# %% [markdown]
# # 18. Explain split() and join() functions in Python?
# The `split()` function in Python divides a string into a list of substrings based on a specified delimiter. The `join()` function combines a list of strings into a single string with a specified delimiter.

# %%
text = "Hello, World!"
# Splitting the string by space
split_text = text.split(' ')
print(split_text)  # Output: ['Hello,', 'World!']

# Joining the list into a string with space
joined_text = ' '.join(split_text)
print(joined_text)

# %% [markdown]
# # 19. What are iterators, iterable, and generators in Python?
# An iterable is an object capable of returning its members one at a time, such as lists, tuples, and strings. An iterator is an object representing a stream of data; it implements the `__iter__()` and `__next__()` methods. Generators are a simple way of creating iterators using functions and the `yield` statement.

# %%
# Iterable example
my_list = [1, 2, 3]
for item in my_list:
    print(item)

# Iterator example
my_iter = iter(my_list)
print(next(my_iter))  # Output: 1
print(next(my_iter))  # Output: 2

# Generator example
def my_generator():
    yield 1
    yield 2
    yield 3
    
for value in my_generator():
    print(value)

# %% [markdown]
# # 20. What is the difference between xrange and range in Python?
# In Python 2, `xrange` returns an xrange object which generates numbers on demand and is more memory efficient, while `range` returns a list of numbers. In Python 3, `xrange` is removed, and `range` behaves like `xrange` in Python 2, generating numbers on demand.

# %%
range(5)

# %%
print(range(5))  
print(list(range(5)))

# %% [markdown]
# # 21. Pillars of OOPs
# The four main pillars of Object-Oriented Programming (OOP) are:
#
# 1. **Encapsulation**: Bundling data and methods that operate on the data within a single unit or class.
# 2. **Abstraction**: Hiding complex implementation details and showing only the necessary features of an object.
# 3. **Inheritance**: Mechanism by which one class inherits attributes and methods from another class.
# 4. **Polymorphism**: Ability to take many forms, allowing methods to do different things based on the object it is acting upon.

# %% [markdown]
# # 22. How will you check if a class is a child of another class?
# You can check if a class is a child of another class using the `issubclass()` function or the `isinstance()` function.

# %%
class Parent:
    pass

class Child(Parent):
    pass

print(issubclass(Child, Parent))  
child_instance = Child()
print(isinstance(child_instance, Parent))

# %% [markdown]
# # 23. How does inheritance work in Python? Explain all types of inheritance with an example.
# Inheritance in Python allows one class (child) to inherit attributes and methods from another class (parent). The types of inheritance are:
#
# 1. **Single Inheritance**: Child class inherits from one parent class.
# 2. **Multiple Inheritance**: Child class inherits from multiple parent classes.
# 3. **Multilevel Inheritance**: A class is derived from a class which is also derived from another class.
# 4. **Hierarchical Inheritance**: Multiple child classes inherit from a single parent class.
# 5. **Hybrid Inheritance**: Combination of two or more types of inheritance.

# %%
# Single Inheritance
class Parent:
    def parent_method(self):
        print("Parent method")

class Child(Parent):
    def child_method(self):
        print("Child method")

c = Child()
c.parent_method()
c.child_method()

# Multiple Inheritance
class Father:
    def father_method(self):
        print("Father method")

class Mother:
    def mother_method(self):
        print("Mother method")

class Child(Father, Mother):
    def child_method(self):
        print("Child method")

c = Child()
c.father_method()
c.mother_method()
c.child_method()

# %% [markdown]
# # 24. What is encapsulation? Explain it with an example.
# Encapsulation is the bundling of data and methods that operate on the data within a single unit or class. It restricts direct access to some of the object's components and can prevent accidental modification.

# %% [markdown]
# class MyClass:
#     def __init__(self):
#         self.__private_var = 10  # Private variable
#
#     def get_private_var(self):
#         return self.__private_var
#
#     def set_private_var(self, value):
#         self.__private_var = value
#
# obj = MyClass()
# print(obj.get_private_var())
# obj.set_private_var(20)
# print(obj.get_private_var())

# %% [markdown]
# # 25. What is polymorphism? Explain it with an example.
# Polymorphism allows methods to do different things based on the object it is acting upon. It can be achieved through method overriding and method overloading.

# %%
# Method Overriding
class Animal:
    def sound(self):
        raise NotImplementedError("Subclass must implement abstract method")

class Dog(Animal):
    def sound(self):
        return "Woof"

class Cat(Animal):
    def sound(self):
        return "Meow"

animals = [Dog(), Cat()]
for animal in animals:
    print(animal.sound())

# Method Overloading (Python does not support traditional method overloading)
def add(a, b, c=0):
    return a + b + c

print(add(1, 2))  # Output: 3
print(add(1, 2, 3))  # Output: 6

# %% [markdown]
# # *QUESTION 1.2* Which of the following identifier names are invalid and why?

# %% [markdown]
# Serial_no.: Identifiers cannot end with a period or contain special characters like periods. They must start with a letter or underscore and can include letters, digits, and underscores.
#
# 1st_Room:Identifiers cannot start with a digit. They must begin with a letter or underscore.
#
# Hundred$:Identifiers can only include letters, digits (after the first character), and underscores. Special characters like $ are not allowed.
#
# total-Marks: Identifiers cannot include hyphens (-). They can only contain letters, digits (after the first character), and underscores.
#
# Total Marks: Identifiers cannot contain spaces. They must be a single contiguous string of characters.
#
# True: True is a reserved keyword in Python. You cannot use it as an identifier name

# %% [markdown]
# # *QUESTION 1.3*

# %% [markdown]
# a) Add an element "freedom_fighter" at the 0th index

# %%
name = ["Mohan", "dash", "karam", "chandra", "gandhi", "Bapu"]
name.insert(0, "freedom_fighter")
print(name)

# %% [markdown]
# b) Find the output and explain

# %%
name = ["freedomFighter", "Bapuji", "MOhan", "dash", "karam", "chandra", "gandhi"]

length1 = len(name[-len(name)+1:-1:2])
length2 = len(name[-len(name)+1:-1])
print(length1 + length2)

# %% [markdown]
# name[-len(name)+1:-1:2]:
#
# -len(name)+1 computes to -7 + 1 = -6.
# The slice name[-6:-1:2] corresponds to the sublist from index -6 to -1 (excluding -1), with a step of 2.
# The sublist is ["Bapuji", "dash", "chandra"].
# Its length is 3.
#
#
# name[-len(name)+1:-1]:
#
# This is the slice name[-6:-1], which corresponds to ["Bapuji", "MOhan", "dash", "karam", "chandra"].
# Its length is 5

# %%
print(length1 + length2)

# %% [markdown]
# c) Add two more elements ["NetaJi", "Bose"] at the end of the list

# %%
name = ['freedom_fighter', 'Mohan', 'dash', 'karam', 'chandra', 'gandhi', 'Bapu']
name.extend(["NetaJi", "Bose"])
print(name)

# %% [markdown]
# d) Swap the first and last elements of the list

# %%
name = ["Bapuji", "dash", "karam", "chandra", "gandi", "Mohan"]
temp = name[-1]
name[-1] = name[0]
name[0] = temp
print(name)

# %% [markdown]
# # *QUESTION 1.4* Find the output

# %%
animal = ['Human', 'cat', 'mat', 'cat', 'rat', 'Human', 'Lion']
print(animal.count('Human'))
print(animal.index('rat'))
print(len(animal))

# %% [markdown]
# # *QUESTION 1.5*

# %%
tuple1 = (10, 20, "Apple", 3.4, 'a', ["master", "ji"], ("sita", "geeta", 22), [{"roll_no": "q1"}, {"name": "Navneet"}])

# a) print(len(tuple1))
print(len(tuple1))

# b) print(tuple1[-1][-1]["name"])
print(tuple1[-1][-1]["name"])

# c) fetch the value of roll_no from this tuple.
print(tuple1[-1][0]["roll_no"])

# d) print(tuple1[-3][1])
print(tuple1[-3][1])

# e) fetch the element "22" from this tuple
print(tuple1[-2][2])

# %% [markdown]
# # *QUESTION 1.6*

# %%
signal = input("Enter the color of the signal (RED/YELLOW/GREEN): ").upper()

if signal == "RED":
    print("Stop")
elif signal == "YELLOW":
    print("Stay")
elif signal == "GREEN":
    print("Go")
else:
    print("Invalid color")

# %% [markdown]
# # *QUESTION 1.7*

# %%
def calculator():
    operation = input("Enter operation (+, -, *, /): ")
    num1 = float(input("Enter first number: "))
    num2 = float(input("Enter second number: "))

    if operation == "+":
        print(num1 + num2)
    elif operation == "-":
        print(num1 - num2)
    elif operation == "*":
        print(num1 * num2)
    elif operation == "/":
        if num2 != 0:
            print(num1 / num2)
        else:
            print("Division by zero is not allowed")
    else:
        print("Invalid operation")

calculator()

# %% [markdown]
# # *QUESTION 1.8*

# %%
num1, num2, num3 = 10, 20, 30
largest = num1 if (num1 > num2 and num1 > num3) else (num2 if num2 > num3 else num3)
print(largest)

# %% [markdown]
# # *QUESTION 1.9*

# %%
num = int(input("Enter a whole number: "))
i = 1
while i <= num:
    if num % i == 0:
        print(i)
    i += 1

# %% [markdown]
# # *QUESTION 1.10*

# %%
total_sum = 0
while True:
    number = float(input("Enter a positive number (or a negative number to stop): "))
    if number < 0:
        break
    total_sum += number

print("Sum of positive numbers:", total_sum)

# %% [markdown]
# # *QUESTION 1.11*

# %%
for num in range(2, 101):
    is_prime = True
    for i in range(2, int(num**0.5) + 1):
        if num % i == 0:
            is_prime = False
            break
    if is_prime:
        print(num)

# %% [markdown]
# # *QUESTION 1.12*

# %%
# Accepting marks for five major subjects
marks = []
subjects = ["Math", "Science", "English", "History", "Geography"]

for subject in subjects:
    mark = float(input(f"Enter marks for {subject}: "))
    marks.append(mark)

# Displaying marks
print("Marks in each subject:", marks)

# Calculating total marks and percentage
total_marks = sum(marks)
percentage = total_marks / len(subjects)

print("Total Marks:", total_marks)
print("Percentage:", percentage)

# Finding the grade
match percentage:
    case p if p >= 85:
        grade = "A"
    case p if p >= 75:
        grade = "B"
    case p if p >= 50:
        grade = "C"
    case p if p >= 30:
        grade = "D"
    case _:
        grade = "REAPPEAR"

print("Grade:", grade)

# %% [markdown]
# # *QUESTION 1.14*

# %%
# Constants
G = 6.67430e-11  # Gravitational constant in m^3 kg^-1 s^-2

# Given data
mass_earth = 5.972e24  # Mass of Earth in kilograms
mass_moon = 7.34767309e22  # Mass of Moon in kilograms
mass_sun = 1.989e30  # Mass of Sun in kilograms
distance_earth_sun = 1.496e11  # Average distance between Earth and Sun in meters
distance_moon_earth = 3.844e8  # Average distance between Moon and Earth in meters

# Calculating the gravitational force between Earth and Sun
force_earth_sun = (G * mass_earth * mass_sun) / (distance_earth_sun ** 2)

# Calculating the gravitational force between Moon and Earth
force_moon_earth = (G * mass_moon * mass_earth) / (distance_moon_earth ** 2)

# Output the forces
print(f"Gravitational force between Earth and Sun: {force_earth_sun:.2e} N")
print(f"Gravitational force between Moon and Earth: {force_moon_earth:.2e} N")

# Comparing the forces
if force_earth_sun > force_moon_earth:
    print("The gravitational force between Earth and the Sun is stronger.")
    print("The Earth is more attracted to the Sun compared to the Moon being attracted to the Earth.")
else:
    print("The gravitational force between Moon and Earth is stronger.")
    print("The Moon is more attracted to the Earth compared to the Earth being attracted to the Sun.")

# %% [markdown]
# # *QUESTION 1.13*

# %%
def classify_color(wavelength):
    if 400 <= wavelength < 440:
        return "Violet"
    elif 440 <= wavelength < 460:
        return "Indigo"
    elif 460 <= wavelength < 500:
        return "Blue"
    elif 500 <= wavelength < 570:
        return "Green"
    elif 570 <= wavelength < 590:
        return "Yellow"
    elif 590 <= wavelength < 620:
        return "Orange"
    elif 620 <= wavelength <= 720:
        return "Red"
    else:
        return "Out of VIBGYOR Range"

# Example usage
wavelength = float(input("Enter the wavelength (in nm): "))
color = classify_color(wavelength)
print(f"The color corresponding to the wavelength {wavelength} nm is {color}.")

# %% [markdown]
# # *QUESTION 2*

# %%
class Student:
    def __init__(self, name, age, roll_number):
        self.__name = name
        self.__age = age
        self.__roll_number = roll_number

    # Getter methods
    def get_name(self):
        return self.__name

    def get_age(self):
        return self.__age

    def get_roll_number(self):
        return self.__roll_number

    # Setter methods
    def set_name(self, name):
        self.__name = name

    def set_age(self, age):
        self.__age = age

    def set_roll_number(self, roll_number):
        self.__roll_number = roll_number

    # Method to display student information
    def display_info(self):
        print(f"Name: {self.__name}")
        print(f"Age: {self.__age}")
        print(f"Roll Number: {self.__roll_number}")

    # Method to update student details
    def update_details(self, name=None, age=None, roll_number=None):
        if name is not None:
            self.__name = name
        if age is not None:
            self.__age = age
        if roll_number is not None:
            self.__roll_number = roll_number


# Creating instances of Student class and testing functionality
student1 = Student("John Doe", 20, "S12345")
student2 = Student("Jane Smith", 22, "S67890")

# Displaying information
student1.display_info()
student2.display_info()

# Updating details
student1.update_details(name="Johnathan Doe", age=21)
student1.display_info()

# %% [markdown]
# # *QUESTION 3*

# %%
class LibraryBook:
    def __init__(self, book_name, author, is_available=True):
        self.__book_name = book_name
        self.__author = author
        self.__is_available = is_available

    # Method to borrow a book
    def borrow_book(self):
        if self.__is_available:
            self.__is_available = False
            print(f"You have borrowed '{self.__book_name}'.")
        else:
            print(f"'{self.__book_name}' is not available.")

    # Method to return a book
    def return_book(self):
        if not self.__is_available:
            self.__is_available = True
            print(f"'{self.__book_name}' has been returned.")
        else:
            print(f"'{self.__book_name}' was not borrowed.")

    # Method to display book information
    def display_info(self):
        status = "Available" if self.__is_available else "Not Available"
        print(f"Book Name: {self.__book_name}")
        print(f"Author: {self.__author}")
        print(f"Status: {status}")


# Creating instances of LibraryBook class and testing functionality
book1 = LibraryBook("1984", "George Orwell")
book2 = LibraryBook("To Kill a Mockingbird", "Harper Lee", False)

# Displaying book information
book1.display_info()
book2.display_info()

# Borrowing and returning books
book1.borrow_book()
book1.return_book()
book2.return_book()

# %% [markdown]
# # *QUESTION 4*

# %%
# *QUESTION 4*

class BankAccount:
    def __init__(self, balance=0):
        self.__balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited {amount}. New balance: {self.__balance}.")
        else:
            print("Deposit amount must be positive.")

    def withdraw(self, amount):
        if amount > 0 and amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrew {amount}. New balance: {self.__balance}.")
        elif amount > self.__balance:
            print("Insufficient funds.")
        else:
            print("Withdrawal amount must be positive.")

    def get_balance(self):
        return self.__balance


class SavingsAccount(BankAccount):
    def __init__(self, balance=0, interest_rate=0.01):
        super().__init__(balance)
        self.__interest_rate = interest_rate

    def apply_interest(self):
        interest = self.get_balance() * self.__interest_rate
        self.deposit(interest)


class CheckingAccount(BankAccount):
    def __init__(self, balance=0, overdraft_limit=100):
        super().__init__(balance)
        self.__overdraft_limit = overdraft_limit

    def withdraw(self, amount):
        if amount > 0 and (self.get_balance() + self.__overdraft_limit) >= amount:
            super().withdraw(amount)
        else:
            print("Insufficient funds or overdraft limit exceeded.")


# Creating instances of different account types and performing transactions
savings = SavingsAccount(balance=500, interest_rate=0.02)
checking = CheckingAccount(balance=200, overdraft_limit=50)

# Testing SavingsAccount
savings.deposit(100)
savings.apply_interest()
savings.withdraw(50)
print(f"Savings Account Balance: {savings.get_balance()}")

# Testing CheckingAccount
checking.deposit(100)
checking.withdraw(250)
print(f"Checking Account Balance: {checking.get_balance()}")

# %% [markdown]
# # *QUESTION 5*

# %%
class Animal:
    def make_sound(self):
        raise NotImplementedError("Subclasses must implement this method.")

class Dog(Animal):
    def make_sound(self):
        print("Woof!")

class Cat(Animal):
    def make_sound(self):
        print("Meow!")


# Creating instances of Dog and Cat and testing the make_sound method
dog = Dog()
cat = Cat()

dog.make_sound()
cat.make_sound()

# %% [markdown]
# # *QUESTION 6*

# %%
class MenuItem:
    def __init__(self, name, description, price, category):
        self.__name = name
        self.__description = description
        self.__price = price
        self.__category = category
        self.__item_id = id(self)  # Unique identification number

    # Getter methods
    def get_name(self):
        return self.__name

    def get_description(self):
        return self.__description

    def get_price(self):
        return self.__price

    def get_category(self):
        return self.__category

    def get_item_id(self):
        return self.__item_id

    # Setter methods
    def set_name(self, name):
        self.__name = name

    def set_description(self, description):
        self.__description = description

    def set_price(self, price):
        self.__price = price

    def set_category(self, category):
        self.__category = category

    # Method to display item information
    def display_info(self):
        print(f"Name: {self.__name}")
        print(f"Description: {self.__description}")
        print(f"Price: {self.__price}")
        print(f"Category: {self.__category}")

    # Method to update item information
    def update_info(self, name=None, description=None, price=None, category=None):
        if name is not None:
            self.__name = name
        if description is not None:
            self.__description = description
        if price is not None:
            self.__price = price
        if category is not None:
            self.__category = category


class FoodItem(MenuItem):
    def __init__(self, name, description, price, category, spice_level):
        super().__init__(name, description, price, category)
        self.__spice_level = spice_level

    def get_spice_level(self):
        return self.__spice_level

    def set_spice_level(self, spice_level):
        self.__spice_level = spice_level

    def display_info(self):
        super().display_info()
        print(f"Spice Level: {self.__spice_level}")


class BeverageItem(MenuItem):
    def __init__(self, name, description, price, category, size):
        super().__init__(name, description, price, category)
        self.__size = size

    def get_size(self):
        return self.__size

    def set_size(self, size):
        self.__size = size

    def display_info(self):
        super().display_info()
        print(f"Size: {self.__size}")


# Testing the Restaurant Management System
food_item = FoodItem("Spicy Curry", "Hot and spicy curry.", 12.99, "Main Course", "High")
beverage_item = BeverageItem("Lemonade", "Refreshing lemonade.", 5.49, "Beverage", "Medium")

food_item.display_info()
beverage_item.display_info()

food_item.update_info(price=13.49)
food_item.display_info()

# %% [markdown]
# # *QUESTION 7*

# %%
class Room:
    def __init__(self, room_number, room_type, rate, availability):
        self.__room_number = room_number
        self.__room_type = room_type
        self.__rate = rate
        self.__availability = availability

    # Method to book a room
    def book_room(self):
        if self.__availability:
            self.__availability = False
            print(f"Room {self.__room_number} booked successfully.")
        else:
            print(f"Room {self.__room_number} is already booked.")

    # Method to check in a guest
    def check_in(self):
        if not self.__availability:
            print(f"Guest checked into room {self.__room_number}.")
        else:
            print(f"Room {self.__room_number} is available. Cannot check in.")

    # Method to check out a guest
    def check_out(self):
        if not self.__availability:
            self.__availability = True
            print(f"Guest checked out of room {self.__room_number}.")
        else:
            print(f"Room {self.__room_number} is already available.")

    def get_availability(self):
        return self.__availability

    def get_room_number(self):
        return self.__room_number

    def get_rate(self):
        return self.__rate

    def get_room_type(self):
        return self.__room_type


class SuiteRoom(Room):
    def __init__(self, room_number, rate, availability, suite_type):
        super().__init__(room_number, "Suite", rate, availability)
        self.__suite_type = suite_type

    def get_suite_type(self):
        return self.__suite_type

    def display_info(self):
        print(f"Room Number: {self.get_room_number()}")
        print(f"Room Type: Suite")
        print(f"Rate: {self.get_rate()}")
        print(f"Availability: {self.get_availability()}")
        print(f"Suite Type: {self.__suite_type}")


class StandardRoom(Room):
    def __init__(self, room_number, rate, availability, bed_type):
        super().__init__(room_number, "Standard", rate, availability)
        self.__bed_type = bed_type

    def get_bed_type(self):
        return self.__bed_type

    def display_info(self):
        print(f"Room Number: {self.get_room_number()}")
        print(f"Room Type: Standard")
        print(f"Rate: {self.get_rate()}")
        print(f"Availability: {self.get_availability()}")
        print(f"Bed Type: {self.__bed_type}")


# Testing the Hotel Management System
suite = SuiteRoom(101, 200, True, "Luxury")
standard = StandardRoom(102, 100, True, "Queen")

suite.book_room()
standard.check_in()
suite.display_info()
standard.display_info()
standard.check_out()

# %% [markdown]
# # *QUESTION 8*

# %%
class FamilyMember:
    def __init__(self, name, age, membership_type, membership_status):
        self.__name = name
        self.__age = age
        self.__membership_type = membership_type
        self.__membership_status = membership_status

    # Getter and Setter for name
    def get_name(self):
        return self.__name

    def set_name(self, name):
        self.__name = name

    # Getter and Setter for age
    def get_age(self):
        return self.__age

    def set_age(self, age):
        self.__age = age

    # Getter and Setter for membership type
    def get_membership_type(self):
        return self.__membership_type

    def set_membership_type(self, membership_type):
        self.__membership_type = membership_type

    # Getter and Setter for membership status
    def get_membership_status(self):
        return self.__membership_status

    def set_membership_status(self, membership_status):
        self.__membership_status = membership_status

    # Method to register a new member
    def register_member(self):
        print(f"Member {self.__name} registered with status {self.__membership_status}.")

    # Method to renew membership
    def renew_membership(self):
        self.__membership_status = "Active"
        print(f"Membership for {self.__name} renewed.")

    # Method to cancel membership
    def cancel_membership(self):
        self.__membership_status = "Cancelled"
        print(f"Membership for {self.__name} cancelled.")

class IndividualMember(FamilyMember):
    def __init__(self, name, age, membership_type, membership_status):
        super().__init__(name, age, membership_type, membership_status)
        self.__member_type = "Individual"

    def get_member_type(self):
        return self.__member_type

class FamilyMember(FamilyMember):
    def __init__(self, name, age, membership_type, membership_status):
        super().__init__(name, age, membership_type, membership_status)
        self.__member_type = "Family"

    def get_member_type(self):
        return self.__member_type

# Testing the FamilyMember and IndividualMember classes
individual = IndividualMember("Alice", 30, "Gold", "Active")
family_member = FamilyMember("Bob", 40, "Silver", "Inactive")

# Register members
individual.register_member()
family_member.register_member()

# Renew memberships
individual.renew_membership()
family_member.renew_membership()

# Cancel memberships
individual.cancel_membership()
family_member.cancel_membership()

# Print member details
print(f"Individual Member: {individual.get_name()}, {individual.get_age()}, {individual.get_membership_type()}, {individual.get_membership_status()}, {individual.get_member_type()}")
print(f"Family Member: {family_member.get_name()}, {family_member.get_age()}, {family_member.get_membership_type()}, {family_member.get_membership_status()}, {family_member.get_member_type()}")

# %% [markdown]
# # *QUESTION 9*

# %%
class Event:
    def __init__(self, name, date, time, location):
        self.__name = name
        self.__date = date
        self.__time = time
        self.__location = location
        self.__attendees = []
        self.__event_id = id(self)  # Unique identification number

    def add_attendee(self, attendee):
        self.__attendees.append(attendee)
        print(f"{attendee} added to the event.")

    def remove_attendee(self, attendee):
        if attendee in self.__attendees:
            self.__attendees.remove(attendee)
            print(f"{attendee} removed from the event.")
        else:
            print(f"{attendee} not found in the list.")

    def get_total_attendees(self):
        return len(self.__attendees)

    def get_event_id(self):
        return self.__event_id


class PrivateEvent(Event):
    def __init__(self, name, date, time, location, guest_list):
        super().__init__(name, date, time, location)

# %% [markdown]
# # *QUESTION 10*

# %%
class Flight:
    def __init__(self, flight_number, departure_airport, arrival_airport, departure_time, arrival_time, available_seats):
        self.__flight_number = flight_number
        self.__departure_airport = departure_airport
        self.__arrival_airport = arrival_airport
        self.__departure_time = departure_time
        self.__arrival_time = arrival_time
        self.__available_seats = available_seats

    # Method to book a seat
    def book_seat(self):
        if self.__available_seats > 0:
            self.__available_seats -= 1
            print(f"Seat booked successfully. Remaining seats: {self.__available_seats}")
        else:
            print("No seats available.")

    # Method to cancel a reservation
    def cancel_reservation(self):
        self.__available_seats += 1
        print(f"Reservation cancelled. Remaining seats: {self.__available_seats}")

    # Method to get remaining available seats
    def get_available_seats(self):
        return self.__available_seats

    # Method to get flight details
    def get_flight_details(self):
        return {
            "Flight Number": self.__flight_number,
            "Departure Airport": self.__departure_airport,
            "Arrival Airport": self.__arrival_airport,
            "Departure Time": self.__departure_time,
            "Arrival Time": self.__arrival_time,
            "Available Seats": self.__available_seats
        }

class DomesticFlight(Flight):
    def __init__(self, flight_number, departure_airport, arrival_airport, departure_time, arrival_time, available_seats, domestic_route):
        super().__init__(flight_number, departure_airport, arrival_airport, departure_time, arrival_time, available_seats)
        self.__domestic_route = domestic_route

    def get_domestic_route(self):
        return self.__domestic_route

    def get_flight_details(self):
        details = super().get_flight_details()
        details["Domestic Route"] = self.__domestic_route
        return details

class InternationalFlight(Flight):
    def __init__(self, flight_number, departure_airport, arrival_airport, departure_time, arrival_time, available_seats, international_route):
        super().__init__(flight_number, departure_airport, arrival_airport, departure_time, arrival_time, available_seats)
        self.__international_route = international_route

    def get_international_route(self):
        return self.__international_route

    def get_flight_details(self):
        details = super().get_flight_details()
        details["International Route"] = self.__international_route
        return details

# Testing the Airline Reservation System
domestic_flight = DomesticFlight("DF123", "JFK", "LAX", "2024-08-01 10:00", "2024-08-01 13:00", 100, "NY to LA")
international_flight = InternationalFlight("IF456", "JFK", "LHR", "2024-08-01 20:00", "2024-08-02 08:00", 200, "NY to London")

# Book seats
domestic_flight.book_seat()
international_flight.book_seat()

# Cancel reservation
domestic_flight.cancel_reservation()

# Print flight details
print(domestic_flight.get_flight_details())
print(international_flight.get_flight_details())

# %% [markdown]
# # *QUESTION 11* Define a Python module named constants.py containing constants like pi and the speed of light.

# %%
# constants.py
PI = 3.14159
SPEED_OF_LIGHT = 299792458  # in meters per second

# %% [markdown]
# # *QUESTION 11* Define a Python module named constants.py containing constants like pi and the speed of light.

# %%
# calculator.py

def add(a, b):
    return a + b

def subtract(a, b):
    return a - b

def multiply(a, b):
    return a * b

def divide(a, b):
    if b != 0:
        return a / b
    else:
        return "Division by zero is not allowed"

# %% [markdown]
# # *QUESTION 13* Implement a Python package structure for a project named ecommerce, containing modules for product management and order processing.

# %%
# Directory structure:
# ecommerce/
#     __init__.py
#     product_management.py
#     order_processing.py

# product_management.py
def add_product(name, price):
    print(f"Product {name} added with price ${price}")

# order_processing.py
def process_order(order_id):
    print(f"Order {order_id} is being processed")

# %% [markdown]
# # *QUESTION 14* Implement a Python module named string_utils.py containing functions for string manipulation, such as reversing and capitalizing strings.

# %%
# string_utils.py

def reverse_string(s):
    return s[::-1]

def capitalize_string(s):
    return s.upper()

# %% [markdown]
# # *QUESTION 15* Write a Python module named file_operations.py with functions for reading, writing, and appending data to a file.

# %%
# file_operations.py

def read_file(filename):
    with open(filename, 'r') as file:
        return file.read()

def write_file(filename, data):
    with open(filename, 'w') as file:
        file.write(data)

def append_to_file(filename, data):
    with open(filename, 'a') as file:
        file.write(data)

# %% [markdown]
# # *QUESTION 16* Write a Python program to create a text file named "employees.txt" and write the details of employees, including their name, age, and salary, into the file.

# %%
with open('employees.txt', 'w') as file:
    file.write("Name, Age, Salary\n")
    file.write("Alice, 30, 50000\n")
    file.write("Bob, 25, 60000\n")
    file.write("Charlie, 35, 55000\n")

# %% [markdown]
# # *QUESTION 17* Develop a Python script that opens an existing text file named "inventory.txt" in read mode and displays the contents of the file line by line.

# %%
with open('employees.txt', 'r') as file:
    for line in file:
        print(line.strip())

# %% [markdown]
# # *QUESTION 18* Create a Python script that reads a text file named "expenses.txt" and calculates the total amount spent on various expenses listed in the file.

# %%
total = 0
with open('expenses.txt', 'r') as file:
    for line in file:
        total += float(line.strip())

print(f"Total amount spent: ${total}")

# %% [markdown]
# # *QUESTION 19* Create a Python program that reads a text file named "paragraph.txt" and counts the occurrences of each word in the paragraph, displaying the results in alphabetical order.

# %%
from collections import Counter
import re

with open('employees.txt', 'r') as file:
    text = file.read()

words = re.findall(r'\b\w+\b', text.lower())
word_counts = Counter(words)

for word, count in sorted(word_counts.items()):
    print(f"{word}: {count}")

# %% [markdown]
# # *QUESTION 20* What do you mean by Measure of Central Tendency and Measures of Dispersion .How it can be calculated.
#
#  Central Tendency: Mean, Median, Mode
# Dispersion: Range, Variance, Standard Deviation

# %%
# *QUESTION 20* What do you mean by Measure of Central Tendency and Measures of Dispersion. How it can be calculated.

import numpy as np
from statistics import mode

# Sample data
data = [3, 7, 5, 9, 5]

# Mean
mean = np.mean(data)

# Median
median = np.median(data)

# Mode
mode_result =mode(data)

print(mean,mode_result,median)

# %% [markdown]
# # *QUESTION 21* What do you mean by skewness.Explain its types.Use graph to show.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Positive skew
data_positive = np.random.exponential(scale=1, size=1000)
plt.hist(data_positive, bins=30, alpha=0.7, color='blue')
plt.title('Positive Skew')
plt.show()

# Negative skew
data_negative = -np.random.exponential(scale=1, size=1000)
plt.hist(data_negative, bins=30, alpha=0.7, color='red')
plt.title('Negative Skew')
plt.show()

# %% [markdown]
# # *QUESTION 22* Explain PROBABILITY MASS FUNCTION (PMF) and PROBABILITY DENSITY FUNCTION (PDF). and what is the difference between them?

# %%
# PMF (Discrete Variables)
from scipy.stats import binom

# Probability mass function for a binomial distribution
pmf = binom.pmf(3, 10, 0.5)
print(f"PMF value: {pmf}")

# PDF (Continuous Variables)
from scipy.stats import norm

# Probability density function for a normal distribution
pdf = norm.pdf(0, 0, 1)
print(f"PDF value: {pdf}")

# %% [markdown]
# # *QUESTION 23* What is correlation. Explain its type in details.what are the methods of determining correlation

# %%
import numpy as np
from scipy.stats import pearsonr

x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 6, 8, 10])
correlation, _ = pearsonr(x, y)
print(f"Pearson correlation coefficient: {correlation}")

# Other methods: Spearman rank correlation, Kendall tau
from scipy.stats import spearmanr, kendalltau

spearman_corr, _ = spearmanr(x, y)
kendall_corr, _ = kendalltau(x, y)

print(f"Spearman correlation coefficient: {spearman_corr}")
print(f"Kendall tau correlation coefficient: {kendall_corr}")

# %% [markdown]
# # *QUESTION 24* Calculate coefficient of correlation between the marks obtained by 10 students in Accountancy and statistics.

# %%
import numpy as np
from scipy.stats import pearsonr

# Data
accountancy = np.array([45, 70, 65, 30, 90, 40, 50, 75, 85, 60])
statistics = np.array([35, 90, 70, 40, 95, 40, 60, 80, 80, 50])

# Pearson correlation coefficient
correlation_coefficient, _ = pearsonr(accountancy, statistics)

print(f"Pearson Correlation Coefficient: {correlation_coefficient}")

# %% [markdown]
# # *QUESTION 25* Discuss the 4 differences between correlation and regression.
#  1. Purpose: Correlation measures strength and direction; Regression predicts values.
#  2. Equation: Correlation gives a coefficient; Regression provides an equation.
#  3. Directionality: Correlation is symmetric; Regression is directional.
#  4. Interpretation: Correlation shows relationship strength; Regression predicts and may imply causation.

# %% [markdown]
# # *QUESTION 26* Find the most likely price at Delhi corresponding to the price of Rs. 70 at Agra from the given correlation coefficient.

# %%
# Given data
corr_coefficient = 0.8
price_agra = 70
mean_price_agra = 100  # Example mean
mean_price_delhi = 110  # Example mean
std_dev_agra = 10  # Example standard deviation
std_dev_delhi = 12  # Example standard deviation

# Calculate the most likely price at Delhi
price_delhi = mean_price_delhi + (price_agra - mean_price_agra) * (std_dev_delhi / std_dev_agra) * corr_coefficient
print(f"Most likely price in Delhi: {price_delhi:.2f}")

# %% [markdown]
# # *QUESTION 27* Analyze partially destroyed data to find mean values, correlation coefficient, and σ of y.

# %%
import numpy as np


# Given data
variance_x = 9
regression_eq1 = (8, -10, -66)  # 8x - 10y = -66
regression_eq2 = (40, -18, 214)  # 40x - 18y = 214

# Calculate means
mean_x = -regression_eq1[2] / regression_eq1[0]
mean_y = -regression_eq2[2] / regression_eq2[1]

# Coefficient of correlation
slope_x_y = regression_eq1[0] / -regression_eq1[1]
slope_y_x = regression_eq2[1] / -regression_eq2[0]
correlation = np.sqrt(slope_x_y * slope_y_x)

# Standard deviation of y
std_dev_y = np.sqrt(variance_x * (1 - correlation ** 2) / (correlation ** 2))
print(f"Mean of x: {mean_x:.2f}")
print(f"Mean of y: {mean_y:.2f}")
print(f"Coefficient of correlation: {correlation:.2f}")
print(f"Standard deviation of y: {std_dev_y:.2f}")

# %% [markdown]
# # *QUESTION 28* What is Normal Distribution? What are the four Assumptions of Normal Distribution?
#
#  Normal Distribution is a bell-shaped curve where data is symmetrically distributed around the mean.
#  Assumptions:
#  1. Symmetry around the mean.
#  2. Mean = Median = Mode.
#  3. 68-95-99.7 Rule: Data within ±1σ, ±2σ, ±3σ.
#  4. Asymptotic: Tails approach but never touch the x-axis.

# %% [markdown]
# # *QUESTION 29* Write all the characteristics or Properties of the Normal Distribution Curve.
#
#  1. Bell-shaped curve.
#  2. Symmetrical around the mean.
#  3. Mean = Median = Mode.
#  4. Asymptotic tails.
#  5. 68-95-99.7 Rule.

# %% [markdown]
# # *QUESTION 30* Which of the following options are correct about Normal Distribution Curve.
#
#  (a) Mean ±0.6745σ covers 50% of the area.
#
#  (b) Mean ±1σ covers 68.268% of the area.
#
#  (c) Mean ±2σ covers 95.45% of the area.
#
#  (d) Mean ±3σ covers 99.73% of the area.
#
#  (e) Only 0.27% area is outside the range μ ±3σ.

# %% [markdown]
# # *QUESTION 31* Calculate percentage of items in specific ranges given mean 60 and standard deviation 10.

# %%
from scipy.stats import norm


mean = 60
std_dev = 10

# Probabilities
prob_60_72 = norm.cdf(72, mean, std_dev) - norm.cdf(60, mean, std_dev)
prob_50_60 = norm.cdf(60, mean, std_dev) - norm.cdf(50, mean, std_dev)
prob_beyond_72 = 1 - norm.cdf(72, mean, std_dev)
prob_70_80 = norm.cdf(80, mean, std_dev) - norm.cdf(70, mean, std_dev)

print(f"Percentage between 60 and 72: {prob_60_72 * 100:.2f}%")
print(f"Percentage between 50 and 60: {prob_50_60 * 100:.2f}%")
print(f"Percentage beyond 72: {prob_beyond_72 * 100:.2f}%")
print(f"Percentage between 70 and 80: {prob_70_80 * 100:.2f}%")

# %% [markdown]
# # *QUESTION 32* Find the proportion of students scoring more than given marks.

# %%
mean = 49
std_dev = 6

# Proportions
prop_more_than_55 = 1 - norm.cdf(55, mean, std_dev)
prop_more_than_70 = 1 - norm.cdf(70, mean, std_dev)

print(f"Proportion scoring more than 55 marks: {prop_more_than_55:.4f}")
print(f"Proportion scoring more than 70 marks: {prop_more_than_70:.4f}")

# %% [markdown]
# # *QUESTION 33* Calculate the number of students with heights in specified ranges.

# %%
mean = 65
std_dev = 5
total_students = 500

# Proportions
prop_greater_than_70 = 1 - norm.cdf(70, mean, std_dev)
prop_between_60_70 = norm.cdf(70, mean, std_dev) - norm.cdf(60, mean, std_dev)

# Number of students
students_greater_than_70 = prop_greater_than_70 * total_students
students_between_60_70 = prop_between_60_70 * total_students

print(f"Number of students with height greater than 70 inches: {students_greater_than_70:.0f}")
print(f"Number of students with height between 60 and 70 inches: {students_between_60_70:.0f}")

# %% [markdown]
# # *QUESTION 34* Explain statistical hypothesis, errors in hypothesis testing, and sample types.
#
#  Statistical Hypothesis: An assumption about a population parameter.
#  Errors:
#  1. Type I Error: Rejecting a true null hypothesis.
#
#  2. Type II Error: Failing to reject a false null hypothesis.
#
#  Sample: Subset of a population.
#
#  Large Samples: Typically n > 30.
#
#  Small Samples: Typically n ≤ 30.

# %% [markdown]
# # *QUESTION 35* Test hypothesis for sample standard deviation of 9.0 against population standard deviation of 10.5.

# %%
from scipy.stats import chi2

sample_size = 25
sample_std_dev = 9.0
population_std_dev = 10.5

# Chi-square test statistic
test_statistic = (sample_size - 1) * (sample_std_dev ** 2) / (population_std_dev ** 2)
p_value = chi2.sf(test_statistic, df=sample_size - 1)

print(f"Chi-square test statistic: {test_statistic:.2f}")
print(f"P-value: {p_value:.4f}")

# %% [markdown]
# # *QUESTION 37* Test if the grade distribution is uniform using χ² test.

# %%
from scipy.stats import chi2_contingency



# Data
grades = ['A', 'B', 'C', 'D', 'E']
observed_frequencies = [15, 17, 30, 22, 16]
total_students = sum(observed_frequencies)

# Expected frequencies for a uniform distribution
expected_frequency = [total_students / len(grades)] * len(grades)

# Perform Chi-square test
chi2_statistic, p_value = chi2_contingency([observed_frequencies, expected_frequency])[:2]

print(f"Chi-square statistic: {chi2_statistic:.2f}")
print(f"P-value: {p_value:.4f}")

# %% [markdown]
# # *QUESTION 39-47 and 49* IN FLASK FILES

# %% [markdown]
#  *QUESTION 48* How would you deploy a Flask application to a production server using Gunicorn and Nginx?
#
#  The deployment process involves these steps:
# # 1. Install Gunicorn: pip install gunicorn
#
#  2. Run Gunicorn to serve the Flask app: gunicorn -w 4 myapp:app
#
#  3. Set up Nginx to proxy requests to Gunicorn.
#
#  Example Nginx configuration:
#  server {
#
#      listen 80;
#
#      server_name your_domain_or_ip;
#
#      location / {
#
#          proxy_pass http://127.0.0.1:8000;
#
#          proxy_set_header Host $host;
#
#          proxy_set_header X-Real-IP $remote_addr;
#
#          proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#
#          proxy_set_header X-Forwarded-Proto $scheme;
#      }
#  }
#
#  Ensure Nginx is restarted to apply the configuration.
#
#  This is a high-level overview; the actual deployment may vary based on server setup and requirements.

# %% [markdown]
# # *QUESTION 50* MACHINE LEARNING

# %%
# **Create a database named Travel_Planner in MySQL, and create a table named bookings in it which has attributes (user_id INT, flight_id INT, hotel_id INT, city_id INT, booking_date DATE). Fill with some dummy values. Now you have to read the content of this table using pandas as a dataframe. Show the output.**

import pandas as pd
import mysql.connector

# Connect to the database
conn = mysql.connector.connect(
    host="localhost",
    user="abhinayaanair",
    password="pass",
    database="Travel_Planner"
)

# Read the table into a DataFrame
df = pd.read_sql("SELECT * FROM bookings", conn)
print(df)

conn.close()

# %% [markdown]
# # *QUESTION 50* MACHINE LEARNING PRACTICAL QUESTION:

# %% [markdown]
# **1. Do the EDA on the given dataset: Lung cancer, and extract some useful information from this.
# Dataset Description:
# Lung cancer is one of the most prevalent and deadly forms of cancer worldwide, presenting significant
# challenges in early detection and effective treatment. To aid in the global effort to understand and combat this
# disease, we are excited to introduce our comprehensive Lung Cancer Dataset.**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dataset.csv')

# %%
df.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   65        1               1        1              2
# 1      F   55        1               2        2              1
# 2      F   78        2               2        1              1
# 3      M   60        2               1        1              1
# 4      F   80        1               1        2              1
#
#    CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  COUGHING  \
# 0                2        1        2         2                  2         2
# 1                1        2        2         2                  1         1
# 2                1        2        1         2                  1         1
# 3                2        1        2         1                  1         2
# 4                1        2        1         2                  1         1
#
#    SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN LUNG_CANCER
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 3000 non-null   object
#  1   AGE                    3000 non-null   int64
#  2   SMOKING                3000 non-null   int64
#  3   YELLOW_FINGERS         3000 non-null   int64
#  4   ANXIETY                3000 non-null   int64
#  5   PEER_PRESSURE          3000 non-null   int64
#  6   CHRONIC_DISEASE        3000 non-null   int64
#  7   FATIGUE                3000 non-null   int64
#  8   ALLERGY                3000 non-null   int64
#  9   WHEEZING               3000 non-null   int64
#  10  ALCOHOL_CONSUMING      3000 non-null   int64
#  11  COUGHING               3000 non-null   int64
#  12  SHORTNESS_OF_BREATH    3000 non-null   int64
#  13  SWALLOWING_DIFFICULTY  3000 non-null   int64
#  14  CHEST_PAIN             3000 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# GENDER                   0
# AGE                      0
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC_DISEASE          0
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 0
# ALCOHOL_CONSUMING        0
# COUGHING                 0
# SHORTNESS_OF_BREATH      0
# SWALLOWING_DIFFICULTY    0
# CHEST_PAIN               0
# LUNG_CANCER              0
# dtype: int64

# %%
df.describe()
# Out:
#                AGE      SMOKING  YELLOW_FINGERS      ANXIETY  PEER_PRESSURE  \
# count  3000.000000  3000.000000     3000.000000  3000.000000    3000.000000
# mean     55.169000     1.491000        1.514000     1.494000       1.499000
# std      14.723746     0.500002        0.499887     0.500047       0.500082
# min      30.000000     1.000000        1.000000     1.000000       1.000000
# 25%      42.000000     1.000000        1.000000     1.000000       1.000000
# 50%      55.000000     1.000000        2.000000     1.000000       1.000000
# 75%      68.000000     2.000000        2.000000     2.000000       2.000000
# max      80.000000     2.000000        2.000000     2.000000       2.000000
#
#        CHRONIC_DISEASE      FATIGUE      ALLERGY     WHEEZING  \
# count      3000.000000  3000.000000  3000.000000  3000.000000
# mean          1.509667     1.489667     1.506667     1.497333
# std           0.499990     0.499977     0.500039     0.500076
# ...

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['AGE'], bins=10, kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='GENDER', data=df)
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='LUNG_CANCER', data=df)
plt.title('Lung Cancer Cases')
plt.xlabel('Lung Cancer')
plt.ylabel('Count')
plt.show()

# %%
numerical_columns = ["AGE", "SMOKING", "YELLOW_FINGERS", "ANXIETY", "PEER_PRESSURE", "CHRONIC_DISEASE", 
                     "FATIGUE", "ALLERGY", "WHEEZING", "ALCOHOL_CONSUMING", "COUGHING", 
                     "SHORTNESS_OF_BREATH", "SWALLOWING_DIFFICULTY", "CHEST_PAIN"]

for col in numerical_columns:
    df[col] = pd.to_numeric(df[col])

# Correlation heatmap
plt.figure(figsize=(14, 10))
sns.heatmap(df[numerical_columns].corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
# Box plots for each feature against lung cancer
for col in numerical_columns:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x='LUNG_CANCER', y=col, data=df)
    plt.title(f'{col} vs Lung Cancer')
    plt.xlabel('Lung Cancer')
    plt.ylabel(col)
    plt.show()

# %% [markdown]
# **2. Do the Eda on this Dataset :Presidential Election Polls 2024 Dataset and extract useful information from
# this:
# Dataset: Nationwide Russian election poll data from March 04, 2024
# Dataset Description:
# This dataset comprises the results of a nationwide presidential election poll conducted on March 4, 2024. The
# data offers various insights but does not align with the official election results. You are encouraged to create
# your notebooks and delve into the data for further exploration.**

# %%
df = pd.read_csv('election2024.csv')

# %%
df.head()
# Out:
#                  id   sex   age federal_district  \
# 0  07169ed8148ce047  male  18.0  north caucasian
# 1  0716a4f3354cecdd  male  23.0  north caucasian
# 2  0716889b304ce79c  male  20.0            volga
# 3  07168e28b5cce563  male  22.0     northwestern
# 4  0716a563914ce549  male  21.0         southern
#
#                                    type_of_city    knows_election_date  \
# 0                                       village     named correct date
# 1                                       village     named correct date
# 2         city with population of less than 50k     named correct date
# 3  city with population of 1 million and higher  not sure or no answer
# 4  city with population of 1 million and higher     named correct date
#
#         will_vote candidate      television_usage      internet_usage  \
# 0        not sure     Putin  several times a week  over 4 hours a day
# 1        not sure     Putin      once half a year  over 4 hours a day
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600 entries, 0 to 1599
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   1600 non-null   object
#  1   sex                  1600 non-null   object
#  2   age                  1600 non-null   float64
#  3   federal_district     1600 non-null   object
#  4   type_of_city         1600 non-null   object
#  5   knows_election_date  1600 non-null   object
#  6   will_vote            1600 non-null   object
#  7   candidate            1600 non-null   object
#  8   television_usage     1600 non-null   object
#  9   internet_usage       1600 non-null   object
#  10  education            1600 non-null   object
#  11  income               1600 non-null   object
#  12  employment           1600 non-null   object
#  13  job_type             692 non-null    object
#  14  company_type         879 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# id                       0
# sex                      0
# age                      0
# federal_district         0
# type_of_city             0
# knows_election_date      0
# will_vote                0
# candidate                0
# television_usage         0
# internet_usage           0
# education                0
# income                   0
# employment               0
# job_type               908
# company_type           721
# weight1                  0
# dtype: int64

# %%
# Summary statistics
df.describe(include='all')
# Out:
#                       id     sex          age federal_district  \
# count               1600    1600  1600.000000             1600
# unique              1600       2          NaN                8
# top     07169ed8148ce047  female          NaN          central
# freq                   1     843          NaN              425
# mean                 NaN     NaN    49.936250              NaN
# std                  NaN     NaN    16.901797              NaN
# min                  NaN     NaN    18.000000              NaN
# 25%                  NaN     NaN    37.000000              NaN
# 50%                  NaN     NaN    49.000000              NaN
# 75%                  NaN     NaN    64.000000              NaN
# max                  NaN     NaN    90.000000              NaN
#
#                             type_of_city knows_election_date       will_vote  \
# count                               1600                1600            1600
# ...

# %%
print(data.dtypes)
# Out:
# GENDER                   object
# AGE                       int64
# SMOKING                   int64
# YELLOW_FINGERS            int64
# ANXIETY                   int64
# PEER_PRESSURE             int64
# CHRONIC_DISEASE           int64
# FATIGUE                   int64
# ALLERGY                   int64
# WHEEZING                  int64
# ALCOHOL_CONSUMING         int64
# COUGHING                  int64
# SHORTNESS_OF_BREATH       int64
# SWALLOWING_DIFFICULTY     int64
# CHEST_PAIN                int64
# LUNG_CANCER              object
# dtype: object

# %%
# Distribution of categorical variables
df['sex'].value_counts()
df['federal_district'].value_counts()
df['type_of_city'].value_counts()
df['knows_election_date'].value_counts()
df['will_vote'].value_counts()
df['candidate'].value_counts()

# Distribution of numerical features
df['age'].describe()
df['television_usage'].value_counts()
df['internet_usage'].value_counts()
df['education'].value_counts()
df['income'].value_counts()
df['employment'].value_counts()
df['job_type'].value_counts()
df['company_type'].value_counts()
# Out:
# company_type
# industry, manufacturing                                                                                                     138
# trade                                                                                                                       113
# education                                                                                                                    85
# Сфера услуг, сервиса, бытового обслуживания Включает в том числе: Прачечная/химчистка, ремонт мебели, часов, ювелирны...     70
# construction, architecture                                                                                                   67
# transportation, storage                                                                                                      51
# farming                                                                                                                      44
# ...

# %%
# Select numeric columns only
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Compute the correlation matrix
correlation_matrix = numeric_df.corr()
print(correlation_matrix)
# Out:
#               age   weight1
# age      1.000000 -0.319715
# weight1 -0.319715  1.000000

# %%
# Convert categorical columns to numeric using one-hot encoding
df_encoded = pd.get_dummies(df, drop_first=True)

# Select numeric columns from the encoded DataFrame
numeric_encoded_df = df_encoded.select_dtypes(include=['float64', 'int64'])

# Compute the correlation matrix
correlation_matrix_encoded = numeric_encoded_df.corr()
print(correlation_matrix_encoded)
# Out:
#               age   weight1
# age      1.000000 -0.319715
# weight1 -0.319715  1.000000

# %%
# Countplot of candidate support
sns.countplot(data=df, x='candidate', palette='viridis')
plt.title('Distribution of Candidate Support')
plt.xticks(rotation=45)
plt.show()
# Out:
# /var/folders/bs/_ch1w8zd1nq7hg0flyfhtzvw0000gn/T/ipykernel_2848/1828432368.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='candidate', palette='viridis')

# %%
# Distribution of age
sns.histplot(df['age'].dropna(), kde=True, bins=20)
plt.title('Age Distribution of Respondents')
plt.show()

# %%
# Distribution of responses by sex
sns.countplot(data=df, x='sex', palette='viridis')
plt.title('Gender Distribution')
plt.show()
# Out:
# /var/folders/bs/_ch1w8zd1nq7hg0flyfhtzvw0000gn/T/ipykernel_2848/1550097750.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='sex', palette='viridis')

# %%
# Distribution of responses by federal district
sns.countplot(data=df, x='federal_district', palette='viridis')
plt.title('Distribution by Federal District')
plt.xticks(rotation=45)
plt.show()
# Out:
# /var/folders/bs/_ch1w8zd1nq7hg0flyfhtzvw0000gn/T/ipykernel_2848/3077777140.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='federal_district', palette='viridis')

# %%
# Voting intention vs. candidate support
sns.countplot(data=df, x='will_vote', hue='candidate', palette='viridis')
plt.title('Voting Intention vs. Candidate Support')
plt.show()

# %%
# Television usage vs. candidate support
sns.countplot(data=df, x='television_usage', hue='candidate', palette='viridis')
plt.title('Television Usage vs. Candidate Support')
plt.xticks(rotation=45)
plt.show()

# Internet usage vs. candidate support
sns.countplot(data=df, x='internet_usage', hue='candidate', palette='viridis')
plt.title('Internet Usage vs. Candidate Support')
plt.xticks(rotation=45)
plt.show()

# %%
# Education level vs. candidate support
sns.countplot(data=df, x='education', hue='candidate', palette='viridis')
plt.title('Education Level vs. Candidate Support')
plt.xticks(rotation=45)
plt.show()

# Income level vs. candidate support
sns.countplot(data=df, x='income', hue='candidate', palette='viridis')
plt.title('Income Level vs. Candidate Support')
plt.xticks(rotation=45)
plt.show()

# %%
# Employment vs. candidate support
sns.countplot(data=df, x='employment', hue='candidate', palette='viridis')
plt.title('Employment Status vs. Candidate Support')
plt.xticks(rotation=45)
plt.show()

# Job type vs. candidate support
sns.countplot(data=df, x='job_type', hue='candidate', palette='viridis')
plt.title('Job Type vs. Candidate Support')
plt.xticks(rotation=45)
plt.show()

# %%
# Compute the correlation matrix
numeric_df = df.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numeric_df.corr()

# Heatmap of the correlation matrix
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
